# %% [markdown]
# # Fase 1 · M04: Dataset Final (Orquestador)
#
# **TFM: Pronóstico del Éxito y del Abandono en los Títulos de Grado de la UJI**
#
# | | |
# |---|---|
# | **Autora** | María José Morte Ruiz |
# | **Institución** | UOC + Universitat Jaume I |
# | **Email** | mjmorteruiz@uoc.edu · morte@uji.es |
# | **Fase** | 1 — Transformación |
# | **Módulo** | M04 — Dataset Final |
#
# ---
#
# ## 🎯 Qué hace
#
# Orquestador que lanza los subnotebooks M04a→M04d en secuencia para construir el dataset final de alumnos con todas las correcciones aplicadas.
#
# ## 📋 Requisitos
#
# - Subnotebooks: `f1_m04a`, `f1_m04b`, `f1_m04c`, `f1_m04d`
# - `data/01_interim/*.parquet`
#
# ## 📤 Genera
#
# | Archivo | Contenido |
# |---|---|
# | `data/02_processed/df_alumno.parquet` | Dataset integrado y corregido |
# | `docs/html/fase1/m04_dataset_final.html` | Informe HTML |
#
# ## 🔄 Flujo
#
# ```
# f1_m04a (unión tablas)
#     ↓ f1_m04b (preinscripción)
#     ↓ f1_m04c (corrección notas)
#     ↓ f1_m04d (corrección vía acceso)
#     → data/02_processed/df_alumno.parquet
# ```
#
# ## ➡️ Siguiente
#
# `f1_m05_dashboard.ipynb` — dashboard resumen de Fase 1

# %%
# ============================================================================
# CELDA 1: CONFIGURACIÓN
# ============================================================================
#
# Configura el entorno y localiza los notebooks a ejecutar.
#
# src.display contiene funciones de presentación visual para Jupyter:
#   - mostrar_banner(): cabecera con título e icono
#   - mostrar_progreso_animado(): spinner mientras se ejecuta
#   - mostrar_completado(): mensaje de éxito con tiempo
#   - mostrar_etapa(): descripción de cada paso
#   - mostrar_resumen_final(): resumen con estadísticas
#   - mostrar_pipeline(): diagrama de etapas
# ============================================================================

import sys
import time
from pathlib import Path
from IPython.display import clear_output

# --- Detectar entorno y localizar ROOT ---
def _encontrar_root(start: Path) -> Path:
    for parent in [start] + list(start.parents):
        if (parent / 'src').is_dir():
            return parent
    raise FileNotFoundError(
        f"No se encontró carpeta 'src/' subiendo desde {start}. "
        f"Verifica que el notebook está dentro de AU_UJI/"
    )

ROOT = _encontrar_root(Path.cwd())


sys.path.insert(0, str(ROOT))

# --- Imports visuales ---
from src.display import (
    mostrar_banner,
    mostrar_progreso_animado,
    mostrar_completado,
    mostrar_etapa,
    mostrar_resumen_final,
    mostrar_pipeline
)

# --- Ruta a los notebooks ---
NOTEBOOKS_DIR = ROOT / 'notebooks' / 'fase1_transformacion'

print(f'📁 ROOT: {ROOT}')
print(f'📓 Notebooks: {NOTEBOOKS_DIR}')
# Out:
# 📁 ROOT: C:\FF\AU_UJI_v2
# 📓 Notebooks: C:\FF\AU_UJI_v2\notebooks\fase1_transformacion

# %%
# ============================================================================
# CELDA 2: BANNER INICIAL
# ============================================================================

mostrar_banner(
    titulo='M04: Creación del Dataset Final',
    subtitulo='9 tablas → 1 dataset unificado',
    icono='🔗',
    color='azul'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #3182ce 0%, #2c5282 100%);
#         padding: 30px 40px;
#         border-radius: 16px;
#         margin: 20px 0;
#         box-shadow: 0 10px 40px rgba(0,0,0,0.2);
#         position: relative;
#         overflow: hidden;
#     ">
#         <div style="
#             position: absolute;
#             top: -50%;
#             left: -50%;
#             width: 200%;
#             height: 200%;
#             background: linear-gradient(
#                 45deg,
#                 transparent 30%,
#                 rgba(255,255,255,0.1) 50%,
#                 transparent 70%
#             );
#             animation: shimmer 3s infinite;
#         "></div>
#         <h2 style="
#             color: white;
#             margin: 0;
#             text-align: center;
#             font-size: 1.8em;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.2);
#             position: relative;
#         ">
#             <span style="font-size: 1.3em; margin-right: 10px;">🔗</span> M04: Creación del Dataset Final
#         </h2>
#
#         <p style="color: rgba(255,255,255,0.9); margin: 12px 0 0 0; text-align: center; font-size: 1.1em;">
#             9 tablas → 1 dataset unificado
#         </p>
#
#     </div>

# %%
# ============================================================================
# CELDA 3: PIPELINE VISUAL
# ============================================================================

ETAPAS = [
    {'titulo': 'M04a: 8 Tablas', 'icono': '📗'},
    {'titulo': 'M04b: +Preinscripción', 'icono': '📙'},
    {'titulo': 'M04c: Notas', 'icono': '📘'},
    {'titulo': 'M04d: Vía Acceso', 'icono': '📕'},
    {'titulo': 'Dataset Final', 'icono': '🎯'}
]

mostrar_pipeline(ETAPAS, etapa_actual=0)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     ">
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: space-between;
#         ">
#
#         <div style="display: flex; align-items: center;">
#             <div class="animate-pulse" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #3182ce;
#                 border: 3px solid #3182ce;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: 0 0 15px rgba(49,130,206,0.5);
#             ">
#                 📗
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: bold;
#                 color: #2d3748;
#             ">M04a: 8 Tablas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📙
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04b: +Preinscripción</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📘
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04c: Notas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📕
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04d: Vía Acceso</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 🎯
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">Dataset Final</span>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 4: EJECUTAR M04a — Unión de 8 tablas
# ============================================================================

mostrar_etapa(
    numero=1,
    titulo='M04a: Unión de Tablas',
    descripcion='Uniendo 8 tablas del Excel principal (expedientes, titulaciones, demográficos...)',
    icono='📗',
    color='verde',
    estado='ejecutando'
)

mostrar_progreso_animado(
    titulo='Procesando M04a',
    descripcion='Cargando parquets, procesando domicilios, creando variables derivadas...',
    icono='⚙️',
    color='verde'
)

inicio_a = time.time()
# %run "{NOTEBOOKS_DIR}/f1_m04a_union_tablas.ipynb"
tiempo_a = time.time() - inicio_a

mostrar_completado(
    mensaje='M04a completado → df_alumno_base.parquet',
    tiempo=tiempo_a,
    color='verde'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp animate-pulse" style="
#         background: #c6f6d5;
#         border: 2px solid #38a169;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 10px 0;
#         opacity: 1;
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         transition: all 0.3s ease;
#     ">
#         <div style="
#             background: #38a169;
#             color: white;
#             width: 45px;
#             height: 45px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-weight: bold;
#             font-size: 1.2em;
#             flex-shrink: 0;
#         ">1</div>
#         <div style="flex: 1;">
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="font-size: 1.3em;">📗</span>
#                 <strong style="font-size: 1.1em; color: #2d3748;">M04a: Unión de Tablas</strong>
#             </div>
#             <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Uniendo 8 tablas del Excel principal (expedientes, titulaciones, demográficos...)</p>
#         </div>
#     </div>
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#         border-left: 5px solid #38a169;
#     ">
#         <div style="display: flex; align-items: center; margin-bottom: 15px;">
#             <span style="font-size: 1.8em; margin-right: 12px;" class="animate-bounce">⚙️</span>
#             <div>
#                 <strong style="color: #276749; font-size: 1.1em;">Procesando M04a</strong>
#                 <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Cargando parquets, procesando domicilios, creando variables derivadas...</p>
#             </div>
#         </div>
#         <div style="
#             background: #e2e8f0;
#             border-radius: 10px;
#             height: 8px;
#             overflow: hidden;
#         ">
#             <div style="
#                 background: linear-gradient(135deg, #38a169 0%, #2f855a 100%);
#                 height: 100%;
#                 border-radius: 10px;
#                 animation: progress 2s ease-in-out infinite;
#             "></div>
#         </div>
#     </div>
# ✓ Directorios verificados: 1
# ✓ ===========================================================================
# ✓ 📌 INFORMACIÓN DEL ENTORNO DEL PROYECTO
# ✓ ===========================================================================
# ✓ 🖥️  Entorno detectado: Local
# ✓ 📂 Ruta base:     C:\FF\AU_UJI_v2
# ✓ 📁 RAW:           C:\FF\AU_UJI_v2\data\00_raw
# ✓ 📁 INTERIM:       C:\FF\AU_UJI_v2\data\01_interim
# ✓ 📁 PROCESSED:     C:\FF\AU_UJI_v2\data\02_processed
# ✓ 📁 FEATURES:      C:\FF\AU_UJI_v2\data\03_features
# ✓ 📁 AUTOML:        C:\FF\AU_UJI_v2\data\automl
# ✓ 📁 NOTEBOOKS:     C:\FF\AU_UJI_v2\notebooks
# ✓ 📄 Excel principal: C:\FF\AU_UJI_v2\data\00_raw\datos_proyecto_sin_preinscrip.xlsx
# ✓ ===========================================================================
#
# 📋 Tablas a unir: 8
#    Excluida: preinscripcion (se une en M04b)
# ============================================================
# CARGANDO TABLAS LIMPIAS
# ============================================================
#    ✅ becas          :     70.524 registros
#    ✅ demograficos   :     30.873 registros
#    ✅ domicilios     :    210.911 registros
#    ✅ expedientes    :    109.568 registros
#    ✅ notas          :    107.908 registros
#    ✅ recibos        :    114.454 registros
#    ✅ titulaciones   :         45 registros
#    ✅ trabajo        :    195.524 registros
#
# ✅ Tablas cargadas: 8
# ============================================================
# PROCESANDO DOMICILIOS
# ============================================================
# ✅ vive_fuera: 13.990 True (12.8%)
# ============================================================
# UNIENDO TABLAS
# ============================================================
# 1. Expedientes (base): 109.568
# 2. + Titulaciones: 109.568
# 3. + Demograficos: 109.568
# 4. + Domicilios: 109.568
# 5. + Becas: 109.568
# 6. + Trabajo: 109.568
# 7. + Notas: 109.568
# 8. + Recibos: 109.568
#
# ✅ Dataset base: 109.568 registros × 33 columnas
# ============================================================
# GUARDANDO
# ============================================================
# ✅ Guardado: df_alumno_base.parquet (2.18 MB)
#    Ruta: C:\FF\AU_UJI_v2\data\02_processed\df_alumno_base.parquet
#    Dimensiones: 109.568 registros × 33 columnas
#
# 📌 Siguiente: f1_m04b_union_preinscripcion.ipynb
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #38a169 0%, #2f855a 100%);
#         color: white;
#         padding: 18px 25px;
#         border-radius: 12px;
#         margin: 15px 0;
#         display: flex;
#         align-items: center;
#         justify-content: space-between;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.15);
#     ">
#         <div style="display: flex; align-items: center;">
#             <span style="font-size: 1.5em; margin-right: 12px;" class="animate-pulse">✅</span>
#             <span style="font-size: 1.05em;">M04a completado → df_alumno_base.parquet</span>
#         </div>
#
#         <span style="
#             background: rgba(255,255,255,0.3);
#             padding: 4px 12px;
#             border-radius: 20px;
#             font-size: 0.85em;
#             margin-left: 10px;
#         ">⏱️ 2.6s</span>
#
#     </div>

# %%
# ============================================================================
# CELDA 5: ACTUALIZAR PIPELINE (M04a completado)
# ============================================================================

mostrar_pipeline(ETAPAS, etapa_actual=1)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     ">
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: space-between;
#         ">
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04a: 8 Tablas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="animate-pulse" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #3182ce;
#                 border: 3px solid #3182ce;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: 0 0 15px rgba(49,130,206,0.5);
#             ">
#                 📙
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: bold;
#                 color: #2d3748;
#             ">M04b: +Preinscripción</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📘
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04c: Notas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📕
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04d: Vía Acceso</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 🎯
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">Dataset Final</span>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 6: EJECUTAR M04b — Unión de Preinscripción + HTML
# ============================================================================

mostrar_etapa(
    numero=2,
    titulo='M04b: Unión de Preinscripción',
    descripcion='Añadiendo datos de preinscripción (vía acceso, orden preferencia, cupo...)',
    icono='📙',
    color='naranja',
    estado='ejecutando'
)

mostrar_progreso_animado(
    titulo='Procesando M04b',
    descripcion='Filtrando UJI, merge de preinscripción, generando HTML con visualizaciones...',
    icono='⚙️',
    color='naranja'
)

inicio_b = time.time()
# %run "{NOTEBOOKS_DIR}/f1_m04b_union_preinscripcion.ipynb"
tiempo_b = time.time() - inicio_b

mostrar_completado(
    mensaje='M04b completado → df_alumno.parquet + HTML',
    tiempo=tiempo_b,
    color='naranja'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp animate-pulse" style="
#         background: #feebc8;
#         border: 2px solid #ed8936;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 10px 0;
#         opacity: 1;
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         transition: all 0.3s ease;
#     ">
#         <div style="
#             background: #ed8936;
#             color: white;
#             width: 45px;
#             height: 45px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-weight: bold;
#             font-size: 1.2em;
#             flex-shrink: 0;
#         ">2</div>
#         <div style="flex: 1;">
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="font-size: 1.3em;">📙</span>
#                 <strong style="font-size: 1.1em; color: #2d3748;">M04b: Unión de Preinscripción</strong>
#             </div>
#             <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Añadiendo datos de preinscripción (vía acceso, orden preferencia, cupo...)</p>
#         </div>
#     </div>
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#         border-left: 5px solid #ed8936;
#     ">
#         <div style="display: flex; align-items: center; margin-bottom: 15px;">
#             <span style="font-size: 1.8em; margin-right: 12px;" class="animate-bounce">⚙️</span>
#             <div>
#                 <strong style="color: #c05621; font-size: 1.1em;">Procesando M04b</strong>
#                 <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Filtrando UJI, merge de preinscripción, generando HTML con visualizaciones...</p>
#             </div>
#         </div>
#         <div style="
#             background: #e2e8f0;
#             border-radius: 10px;
#             height: 8px;
#             overflow: hidden;
#         ">
#             <div style="
#                 background: linear-gradient(135deg, #ed8936 0%, #c05621 100%);
#                 height: 100%;
#                 border-radius: 10px;
#                 animation: progress 2s ease-in-out infinite;
#             "></div>
#         </div>
#     </div>
# ✓ Directorios verificados: 2
# ✓ ===========================================================================
# ✓ 📌 INFORMACIÓN DEL ENTORNO DEL PROYECTO
# ✓ ===========================================================================
# ✓ 🖥️  Entorno detectado: Local
# ✓ 📂 Ruta base:     C:\FF\AU_UJI_v2
# ✓ 📁 RAW:           C:\FF\AU_UJI_v2\data\00_raw
# ✓ 📁 INTERIM:       C:\FF\AU_UJI_v2\data\01_interim
# ✓ 📁 PROCESSED:     C:\FF\AU_UJI_v2\data\02_processed
# ✓ 📁 FEATURES:      C:\FF\AU_UJI_v2\data\03_features
# ✓ 📁 AUTOML:        C:\FF\AU_UJI_v2\data\automl
# ✓ 📁 NOTEBOOKS:     C:\FF\AU_UJI_v2\notebooks
# ✓ 📄 Excel principal: C:\FF\AU_UJI_v2\data\00_raw\datos_proyecto_sin_preinscrip.xlsx
# ✓ ===========================================================================
# ============================================================
# CARGANDO DATASET BASE
# ============================================================
# ✅ Cargado: df_alumno_base.parquet
#    Registros: 109,568
#    Columnas: 33
# ============================================================
# CARGANDO PREINSCRIPCIÓN
# ============================================================
# ✅ Cargado: preinscripcion.parquet
#    Registros totales: 210,986
# ✅ Filtrado UJI (ID=40): 107,218
# ============================================================
# PREPARANDO MERGE
# ============================================================
#    ⚠️ Eliminada columna duplicada: cupo
#
#    Claves merge: ['per_id_ficticio', 'exp_tit_id', 'curso_aca_ini']
#    Columnas nuevas: ['via_acceso', 'orden_preferencia', 'cupo', 'universidad_origen']
# ============================================================
# MERGE
# ============================================================
#
# 📊 Antes del merge:
#    df_alumno: 109,568
#    preinscripcion: 32,598
#
# ✅ Dataset final: 109,568 × 37
#    Cobertura preinscripción: 87.4%
# ============================================================
# GUARDANDO DATASET FINAL
# ============================================================
# ✅ df_alumno.parquet: 2.27 MB
# ✅ df_alumno.csv: 30.71 MB
# Métricas: 109.568 reg, 37 cols, 30.872 alumnos
# ============================================================
# GENERANDO HTML
# ============================================================
# ✅ KPIs
# ✅ Notebooks
# ✅ Pipeline
# ✅ M04a
# ✅ M04b
# ✅ Infografía
# ✅ Grafo
# ✅ Archivos
# ✅ Resumen
# ✅ Script grafo
# ✅ HTML guardado: C:\FF\AU_UJI_v2\docs\html\fase1\m04_dataset_final.html
#
# ✅ HTML generado: C:\FF\AU_UJI_v2\docs\html\fase1\m04_dataset_final.html
#
# ============================================================
# ✅ F1-M04b COMPLETADO
# ============================================================
#
# 📁 Archivos generados:
#    • df_alumno.parquet (2.27 MB)
#    • df_alumno.csv (30.71 MB)
#    • m04_dataset_final.html
#
# 📊 Dataset final (9 tablas unidas):
#    • Registros: 109.568
#    • Columnas: 37
#    • Alumnos: 30.872
#    • Cobertura preinscripción: 87.4%
#
# 📌 Siguiente: f1_m05_grafo_d3.ipynb
# ============================================================
# 🔄 Actualizando index.html...
#   ✅ KPIs: Expedientes: 30.872 | Período: 2010-2020
#   📊 Fases: Fase 5: ⏳ | Fase 6: ⏳ | Fase 7: ✅
#   ✅ C:\FF\AU_UJI_v2\docs\html\index.html
#   ✅ C:\FF\AU_UJI_v2\docs\html\fase7\fase7_index.html
# 🔄 Actualizando index.html...
#   ✅ KPIs: Expedientes: 30.872 | Período: 2010-2020
#   📊 Fases: Fase 5: ⏳ | Fase 6: ⏳ | Fase 7: ✅
#   ✅ C:\FF\AU_UJI_v2\docs\html\index.html
#   ✅ C:\FF\AU_UJI_v2\docs\html\fase7\fase7_index.html
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #ed8936 0%, #c05621 100%);
#         color: white;
#         padding: 18px 25px;
#         border-radius: 12px;
#         margin: 15px 0;
#         display: flex;
#         align-items: center;
#         justify-content: space-between;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.15);
#     ">
#         <div style="display: flex; align-items: center;">
#             <span style="font-size: 1.5em; margin-right: 12px;" class="animate-pulse">✅</span>
#             <span style="font-size: 1.05em;">M04b completado → df_alumno.parquet + HTML</span>
#         </div>
#
#         <span style="
#             background: rgba(255,255,255,0.3);
#             padding: 4px 12px;
#             border-radius: 20px;
#             font-size: 0.85em;
#             margin-left: 10px;
#         ">⏱️ 3.8s</span>
#
#     </div>

# %%
# ============================================================================
# CELDA 7: PIPELINE ACTUALIZADO (M04b completado)
# ============================================================================

mostrar_pipeline(ETAPAS, etapa_actual=2)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     ">
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: space-between;
#         ">
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04a: 8 Tablas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04b: +Preinscripción</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="animate-pulse" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #3182ce;
#                 border: 3px solid #3182ce;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: 0 0 15px rgba(49,130,206,0.5);
#             ">
#                 📘
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: bold;
#                 color: #2d3748;
#             ">M04c: Notas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 📕
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">M04d: Vía Acceso</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 🎯
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">Dataset Final</span>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 8: EJECUTAR M04c — Corrección de Notas de Acceso
# ============================================================================

mostrar_etapa(
    numero=3,
    titulo='M04c: Corrección de Notas',
    descripcion='Normalizando escalas, cascada desde preinscripción y entre cursos...',
    icono='📘',
    color='azul',
    estado='ejecutando'
)

mostrar_progreso_animado(
    titulo='Procesando M04c',
    descripcion='Normalizando notas, rellenando huecos con cascada...',
    icono='⚙️',
    color='azul'
)

inicio_c = time.time()
# %run "{NOTEBOOKS_DIR}/f1_m04c_correccion_notas.ipynb"
tiempo_c = time.time() - inicio_c

mostrar_completado(
    mensaje='M04c completado → notas corregidas',
    tiempo=tiempo_c,
    color='azul'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp animate-pulse" style="
#         background: #bee3f8;
#         border: 2px solid #3182ce;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 10px 0;
#         opacity: 1;
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         transition: all 0.3s ease;
#     ">
#         <div style="
#             background: #3182ce;
#             color: white;
#             width: 45px;
#             height: 45px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-weight: bold;
#             font-size: 1.2em;
#             flex-shrink: 0;
#         ">3</div>
#         <div style="flex: 1;">
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="font-size: 1.3em;">📘</span>
#                 <strong style="font-size: 1.1em; color: #2d3748;">M04c: Corrección de Notas</strong>
#             </div>
#             <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Normalizando escalas, cascada desde preinscripción y entre cursos...</p>
#         </div>
#     </div>
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#         border-left: 5px solid #3182ce;
#     ">
#         <div style="display: flex; align-items: center; margin-bottom: 15px;">
#             <span style="font-size: 1.8em; margin-right: 12px;" class="animate-bounce">⚙️</span>
#             <div>
#                 <strong style="color: #2c5282; font-size: 1.1em;">Procesando M04c</strong>
#                 <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Normalizando notas, rellenando huecos con cascada...</p>
#             </div>
#         </div>
#         <div style="
#             background: #e2e8f0;
#             border-radius: 10px;
#             height: 8px;
#             overflow: hidden;
#         ">
#             <div style="
#                 background: linear-gradient(135deg, #3182ce 0%, #2c5282 100%);
#                 height: 100%;
#                 border-radius: 10px;
#                 animation: progress 2s ease-in-out infinite;
#             "></div>
#         </div>
#     </div>
# ✓ ===========================================================================
# ✓ 📌 INFORMACIÓN DEL ENTORNO DEL PROYECTO
# ✓ ===========================================================================
# ✓ 🖥️  Entorno detectado: Local
# ✓ 📂 Ruta base:     C:\FF\AU_UJI_v2
# ✓ 📁 RAW:           C:\FF\AU_UJI_v2\data\00_raw
# ✓ 📁 INTERIM:       C:\FF\AU_UJI_v2\data\01_interim
# ✓ 📁 PROCESSED:     C:\FF\AU_UJI_v2\data\02_processed
# ✓ 📁 FEATURES:      C:\FF\AU_UJI_v2\data\03_features
# ✓ 📁 AUTOML:        C:\FF\AU_UJI_v2\data\automl
# ✓ 📁 NOTEBOOKS:     C:\FF\AU_UJI_v2\notebooks
# ✓ 📄 Excel principal: C:\FF\AU_UJI_v2\data\00_raw\datos_proyecto_sin_preinscrip.xlsx
# ✓ ===========================================================================
#
# 📂 Rutas:
#    Interim:   C:\FF\AU_UJI_v2\data\01_interim
#    Processed: C:\FF\AU_UJI_v2\data\02_processed
# ============================================================
# CARGANDO DATOS
# ============================================================
# ✅ df_alumno: 109,568 registros × 37 columnas
# ✅ preinscripcion: 210,986 registros
# ============================================================
# DIAGNÓSTICO: ESTADO ACTUAL
# ============================================================
#
# 📊 nota_acceso:
#    Con valor:  98,595 (90.0%)
#    NaN:        10,973 (10.0%)
#    Rango:      [5.0000, 13.8050]
#    Valores >14: 0
#
# 📊 nota_selectividad:
#    Con valor:  95,314 (87.0%)
#    NaN:        14,254 (13.0%)
#    Rango:      [5.0000, 7364.0000]
#    ⚠️ Valores >14: 5
#    Detalle >14: {7364.0: 5}
#
# 📊 Sin NINGUNA nota (ni acceso ni selectividad):
#    10,747 registros (9.8%)
# ============================================================
# DIAGNÓSTICO: NOTAS EN PREINSCRIPCIÓN
# ============================================================
#
# Registros UJI: 107,218 de 210,986 totales
#
# 📊 nota_txt (nota de acceso):
#    Rango: [5.0, 11385.0]
#    ⚠️ Valores >14: 1,897
#    Distribución por escala:
#      5-14   (correctos):  105,321
#      15-140  (÷10):            94
#      141-1400 (÷100):         550
#      >1400   (÷1000):       1,253
#
# 📊 nota_1 (nota selectividad):
#    Rango: [5.0, 9909.0]
#    ⚠️ Valores >14: 60,857
#    Distribución por escala:
#      5-14   (correctos):   46,361
#      15-140  (÷10):         3,294
#      141-1400 (÷100):      15,481
#      >1400   (÷1000):      42,082
# Verificación de normalizar_nota():
#         7.5 → 7.5000
#        75.0 → 7.5000
#       750.0 → 7.5000
#      7500.0 → 7.5000
#        13.5 → 13.5000
#       135.0 → 13.5000
#      1350.0 → 13.5000
#         NaN → NaN
#
# ✅ Todos los valores normalizados están en [5, 14]
# ============================================================
# CORRECCIÓN 1: NORMALIZAR VALORES >14 EN df_alumno
# ============================================================
#
# nota_selectividad >14 antes: 5
# Valores: [7364.]
# nota_selectividad >14 después: 0
#
# ✅ Corregidos 5 valores
# ============================================================
# CORRECCIÓN 2: CASCADA DESDE PREINSCRIPCIÓN
# ============================================================
#
# Registros preinscripción UJI: 107,218
# Registros únicos (agrupados): 101,730
# Matcheados con preinscripción: 82,665 de 109,568
#
# ✅ nota_acceso recuperadas:       +1,399
# ✅ nota_selectividad recuperadas:  +2,564
# ============================================================
# CORRECCIÓN 3: CASCADA INTRA-ALUMNO
# ============================================================
#
# Alumnos sin nota_acceso: 3,158
#   De ellos, 665 tienen nota en otros registros
#
# Alumnos sin nota_selectividad: 3,758
#   De ellos, 728 tienen nota en otros registros
# ✅ nota_acceso propagadas intra-alumno:       +1,754
# ✅ nota_selectividad propagadas intra-alumno:  +1,820
# ============================================================
# VALIDACIÓN
# ============================================================
#
# nota_acceso:
#    Rango: [5.0000, 13.8050]
#    >14: 0 | <5: 0
#
# nota_selectividad:
#    Rango: [5.0000, 12.5360]
#    >14: 0 | <5: 0
#
# ✅ Registros: 109,568 (sin cambios)
# ✅ Columnas: 37 (sin cambios)
# ✅ Todos los valores en rango [5, 14]
# ✅ Validación superada
# ============================================================
# COMPARACIÓN ANTES vs DESPUÉS
# ============================================================
#
# MÉTRICA                                  ANTES    DESPUÉS   GANANCIA
# -------------------------------------------------------------------
# nota_acceso NaN                         10,973      7,820     +3,153
# nota_selectividad NaN                   14,254      9,870     +4,384
# nota_selectividad >14                        5          0         +5
# Sin NINGUNA nota                        10,747      7,771     +2,976
#
# 📊 Desglose de recuperaciones:
#    Cascada preinscripción:  nota_acceso +1,399, nota_selectividad +2,564
#    Cascada intra-alumno:    nota_acceso +1,754, nota_selectividad +1,820
#
# 📊 Rangos:
#    nota_acceso: [5.0000, 13.8050]
#    nota_selectividad: [5.0000, 12.5360]
# ============================================================
# REGISTROS SIN NOTA — ANÁLISIS
# ============================================================
#
# Registros sin ninguna nota: 7,771 (7.1%)
# Alumnos únicos sin nota: 2,481
#
# Por tipo (nuevo S/N):
# nuevo
# N    7680
# S      91
# → 99% son alumnos NO nuevos (adaptaciones, traslados, etc.)
#
# Por curso_aca_ini:
# curso_aca_ini
# 2009    2197
# 2010     870
# 2011     561
# 2012    1577
# 2013    1124
# 2014     510
# 2015     349
# 2016     178
# 2017     172
# 2018     141
# 2019      66
# 2020      26
# → 81% concentrados en 2009-2013 (implantación de Bolonia)
#
# Con vía de acceso: 190 de 7771
# via_acceso
# Pruebas acceso Bachiller Logse                 171
# Ciclo Formativo de Grado sup. o equivalente     10
# Extranjeros CEE                                  6
# Titulados Universitarios                         3
#
# 📝 Conclusión: Los 7,771 registros sin nota son mayoritariamente
#    alumnos NO nuevos de 2009-2013 (adaptación a grado Bolonia).
#    No tienen nota de acceso porque entraron por vías que no la requieren.
#    Quedan como NaN documentado — no es un error, es dato ausente legítimo.
# ============================================================
# GUARDANDO DATASET
# ============================================================
# ✅ df_alumno.parquet: 2.29 MB
# ✅ df_alumno.csv: 30.75 MB
#
# ============================================================
# ✅ F1-M04c: CORRECCIÓN DE NOTAS — COMPLETADO
# ============================================================
#
# Correcciones aplicadas:
#
#   1. Normalización:  5 valores >14 en nota_selectividad → corregidos
#   2. Cascada preinscripción:  nota_acceso +1,399  |  nota_selectividad +2,564
#   3. Cascada intra-alumno:    nota_acceso +1,754  |  nota_selectividad +1,820
#
# Resultado:
#   nota_acceso NaN:       10,973 → 7,820 (recuperados +3,153)
#   nota_selectividad NaN: 14,254 → 9,870 (recuperados +4,384)
#   Sin ninguna nota:      10,747 → 7,771 (NaN documentado)
#
# Archivos actualizados:
#   data/02_processed/df_alumno.parquet
#   data/02_processed/df_alumno.csv
#
# 📌 Siguiente: f1_m04d (corrección vía de acceso — P5)
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #3182ce 0%, #2c5282 100%);
#         color: white;
#         padding: 18px 25px;
#         border-radius: 12px;
#         margin: 15px 0;
#         display: flex;
#         align-items: center;
#         justify-content: space-between;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.15);
#     ">
#         <div style="display: flex; align-items: center;">
#             <span style="font-size: 1.5em; margin-right: 12px;" class="animate-pulse">✅</span>
#             <span style="font-size: 1.05em;">M04c completado → notas corregidas</span>
#         </div>
#
#         <span style="
#             background: rgba(255,255,255,0.3);
#             padding: 4px 12px;
#             border-radius: 20px;
#             font-size: 0.85em;
#             margin-left: 10px;
#         ">⏱️ 3.1s</span>
#
#     </div>

# %%
# ============================================================================
# CELDA 9: PIPELINE ACTUALIZADO (M04c completado)
# ============================================================================

mostrar_pipeline(ETAPAS, etapa_actual=3)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     ">
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: space-between;
#         ">
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04a: 8 Tablas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04b: +Preinscripción</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04c: Notas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="animate-pulse" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #3182ce;
#                 border: 3px solid #3182ce;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: 0 0 15px rgba(49,130,206,0.5);
#             ">
#                 📕
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: bold;
#                 color: #2d3748;
#             ">M04d: Vía Acceso</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #e2e8f0;
#                 border: 3px solid #cbd5e0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: #718096;
#                 box-shadow: none;
#             ">
#                 🎯
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #a0aec0;
#             ">Dataset Final</span>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 10: EJECUTAR M04d — Corrección de Vía de Acceso
# ============================================================================

mostrar_etapa(
    numero=4,
    titulo='M04d: Corrección Vía de Acceso',
    descripcion='Limpiando duplicados, rellenando NaN, renombrando columna...',
    icono='📕',
    color='rojo',
    estado='ejecutando'
)

mostrar_progreso_animado(
    titulo='Procesando M04d',
    descripcion='Unificando vía de acceso, mapeando categorías...',
    icono='⚙️',
    color='rojo'
)

inicio_d = time.time()
# %run "{NOTEBOOKS_DIR}/f1_m04d_correccion_via_acceso.ipynb"
tiempo_d = time.time() - inicio_d

mostrar_completado(
    mensaje='M04d completado → vía de acceso corregida',
    tiempo=tiempo_d,
    color='rojo'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp animate-pulse" style="
#         background: #fed7d7;
#         border: 2px solid #e53e3e;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 10px 0;
#         opacity: 1;
#         display: flex;
#         align-items: center;
#         gap: 15px;
#         transition: all 0.3s ease;
#     ">
#         <div style="
#             background: #e53e3e;
#             color: white;
#             width: 45px;
#             height: 45px;
#             border-radius: 50%;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-weight: bold;
#             font-size: 1.2em;
#             flex-shrink: 0;
#         ">4</div>
#         <div style="flex: 1;">
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="font-size: 1.3em;">📕</span>
#                 <strong style="font-size: 1.1em; color: #2d3748;">M04d: Corrección Vía de Acceso</strong>
#             </div>
#             <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Limpiando duplicados, rellenando NaN, renombrando columna...</p>
#         </div>
#     </div>
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 20px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#         border-left: 5px solid #e53e3e;
#     ">
#         <div style="display: flex; align-items: center; margin-bottom: 15px;">
#             <span style="font-size: 1.8em; margin-right: 12px;" class="animate-bounce">⚙️</span>
#             <div>
#                 <strong style="color: #c53030; font-size: 1.1em;">Procesando M04d</strong>
#                 <p style="margin: 5px 0 0 0; color: #718096; font-size: 0.9em;">Unificando vía de acceso, mapeando categorías...</p>
#             </div>
#         </div>
#         <div style="
#             background: #e2e8f0;
#             border-radius: 10px;
#             height: 8px;
#             overflow: hidden;
#         ">
#             <div style="
#                 background: linear-gradient(135deg, #e53e3e 0%, #c53030 100%);
#                 height: 100%;
#                 border-radius: 10px;
#                 animation: progress 2s ease-in-out infinite;
#             "></div>
#         </div>
#     </div>
# ✓ ===========================================================================
# ✓ 📌 INFORMACIÓN DEL ENTORNO DEL PROYECTO
# ✓ ===========================================================================
# ✓ 🖥️  Entorno detectado: Local
# ✓ 📂 Ruta base:     C:\FF\AU_UJI_v2
# ✓ 📁 RAW:           C:\FF\AU_UJI_v2\data\00_raw
# ✓ 📁 INTERIM:       C:\FF\AU_UJI_v2\data\01_interim
# ✓ 📁 PROCESSED:     C:\FF\AU_UJI_v2\data\02_processed
# ✓ 📁 FEATURES:      C:\FF\AU_UJI_v2\data\03_features
# ✓ 📁 AUTOML:        C:\FF\AU_UJI_v2\data\automl
# ✓ 📁 NOTEBOOKS:     C:\FF\AU_UJI_v2\notebooks
# ✓ 📄 Excel principal: C:\FF\AU_UJI_v2\data\00_raw\datos_proyecto_sin_preinscrip.xlsx
# ✓ ===========================================================================
#
# 📂 Processed: C:\FF\AU_UJI_v2\data\02_processed
# ============================================================
# CARGANDO DATOS
# ============================================================
# ✅ df_alumno: 109,568 registros × 37 columnas
# ============================================================
# DIAGNÓSTICO: DOS VÍAS DE ACCESO
# ============================================================
#
# 📊 Campo "nombre" (de expedientes):
#    Categorías: 20
#    NaN: 0 (0.0%)
#
#    Valores:
#      General                                                  72,725 (66.4%)
#      Selectividad                                             21,812 (19.9%)
#      Adaptación a Grado                                        5,598 (5.1%)
#      Traslado ( a segundo o mas )                              2,511 (2.3%)
#      Majores de 25 años                                        1,972 (1.8%)
#      Titulados Universitarios                                  1,201 (1.1%)
#       Acceso a Grado con título previo                           822 (0.8%)
#      Segunda titulación                                          669 (0.6%)
#      Minusválidos                                                523 (0.5%)
#      Deportistas de élite                                        484 (0.4%)
#      Formacion Profesional/Modulo 3/Ciclos formativos            290 (0.3%)
#      Traslado de estudios extranjeros                            268 (0.2%)
#      Euruji                                                      203 (0.2%)
#      Mayores de 40 años                                          156 (0.1%)
#      Mayores de 45 años                                          151 (0.1%)
#      Cambio de plan de estudios de grado                         150 (0.1%)
#      Intercambio entrante                                         16 (0.0%)
#      Minusválidos - Mayores de 25 años                             6 (0.0%)
#      Deportistas de élite - Titulados Universitarios               6 (0.0%)
#      Minusválidos - Selectividad                                   5 (0.0%)
#
# 📊 Campo "via_acceso" (de preinscripción):
#    Categorías: 11
#    NaN: 13,835 (12.6%)
#
#    Valores:
#      Pruebas acceso Bachiller Logse                           77,267 (70.5%)
#      Ciclo Formativo de Grado sup. o equivalente              13,673 (12.5%)
#      Pruebas acceso mayores 25 años                            1,519 (1.4%)
#      Titulados Universitarios                                  1,285 (1.2%)
#      Extranjeros CEE                                             959 (0.9%)
#      Pruebas acceso mayores 25años                               455 (0.4%)
#      Extranjeros no CEE                                          284 (0.3%)
#      Pruebas acceso mayores 40 años                               89 (0.1%)
#      Pruebas acceso mayores 45años                                82 (0.1%)
#      Pruebas acceso mayores 40años                                73 (0.1%)
#      Pruebas acceso mayores 45 años                               47 (0.0%)
# ============================================================
# LOS 13.835 SIN via_acceso — ¿QUÉ SON?
# ============================================================
#
# Registros sin via_acceso: 13,835
#
# Por campo "nombre":
#   Adaptación a Grado                                       5,502
#   Selectividad                                             2,013
#   General                                                  1,987
#   Traslado ( a segundo o mas )                             1,956
#    Acceso a Grado con título previo                          787
#   Segunda titulación                                         657
#   Traslado de estudios extranjeros                           268
#   Formacion Profesional/Modulo 3/Ciclos formativos           245
#   Cambio de plan de estudios de grado                        148
#   Majores de 25 años                                          84
#   Titulados Universitarios                                    79
#   Minusválidos                                                25
#   Deportistas de élite                                        20
#   Mayores de 45 años                                          19
#   Euruji                                                      17
#   Intercambio entrante                                        16
#   Deportistas de élite - Titulados Universitarios              6
#   Minusválidos - Selectividad                                  5
#   Minusválidos - Mayores de 25 años                            1
#
# 📝 La mayoría son Adaptación a Grado (5.502) y Traslado (1.956):
#    alumnos que no pasaron por preinscripción ordinaria.
#    No tienen via_acceso de preinscripción porque nunca la hicieron.
# ============================================================
# CORRECCIÓN 1: LIMPIAR DUPLICADOS EN via_acceso
# ============================================================
# Categorías: 11 → 8 (fusionados 3 duplicados)
#
# Valores tras limpieza:
#   Pruebas acceso Bachiller Logse                           77,267
#   Ciclo Formativo de Grado sup. o equivalente              13,673
#   Pruebas acceso mayores 25 años                            1,974
#   Titulados Universitarios                                  1,285
#   Extranjeros CEE                                             959
#   Extranjeros no CEE                                          284
#   Pruebas acceso mayores 40 años                              162
#   Pruebas acceso mayores 45 años                              129
# ============================================================
# CORRECCIÓN 2: RELLENAR NaN DESDE "nombre"
# ============================================================
#
# NaN antes:  13,835
# Rellenados: 13,835
# NaN después: 0
#
# ✅ Todos los registros tienen via_acceso
# ============================================================
# CORRECCIÓN 3: RENOMBRAR nombre → via_acceso_exp
# ============================================================
#
# ✅ Renombrado: nombre → via_acceso_exp
#    Columnas actuales: 37
# ============================================================
# VALIDACIÓN
# ============================================================
#
# ✅ via_acceso: 0 NaN
#    Categorías: 13
# ✅ via_acceso_exp: 0 NaN (renombrado desde nombre)
# ✅ Registros: 109,568 (sin cambios)
# ✅ Columnas: 37 (sin cambios, solo renombre)
# ✅ Validación superada
# ============================================================
# COMPARACIÓN ANTES vs DESPUÉS
# ============================================================
#
# MÉTRICA                                  ANTES    DESPUÉS
# ---------------------------------------------------------
# via_acceso NaN                          13,835          0
# via_acceso categorías                       11         13
# Duplicados espaciado                   3 pares          0
# Campo nombre                            nombre via_acc_exp
#
# 📊 via_acceso final (13 categorías):
#   Pruebas acceso Bachiller Logse                           81,272 (74.2%)
#   Ciclo Formativo de Grado sup. o equivalente              13,918 (12.7%)
#   Adaptación a Grado                                        5,502 (5.0%)
#   Titulados Universitarios                                  2,814 (2.6%)
#   Pruebas acceso mayores 25 años                            2,059 (1.9%)
#   Traslado                                                  1,956 (1.8%)
#   Extranjeros CEE                                             992 (0.9%)
#   Extranjeros no CEE                                          552 (0.5%)
#   Pruebas acceso mayores 40 años                              162 (0.1%)
#   Pruebas acceso mayores 45 años                              148 (0.1%)
#   Cambio de plan                                              148 (0.1%)
#   Minusválidos                                                 25 (0.0%)
#   Deportistas de élite                                         20 (0.0%)
# ============================================================
# GUARDANDO DATASET
# ============================================================
# ✅ df_alumno.parquet: 2.29 MB
# ✅ df_alumno.csv: 31.04 MB
#
# ============================================================
# ✅ F1-M04d: CORRECCIÓN VÍA DE ACCESO — COMPLETADO
# ============================================================
#
# Correcciones aplicadas:
#
#   1. Limpieza duplicados: 3 pares fusionados ("25años" → "25 años")
#   2. Cascada nombre → via_acceso: 13,835 NaN rellenados
#      - Mapeo directo a categorías existentes (General → Bachiller Logse, etc.)
#      - Categorías propias para los que no encajan (Adaptación, Traslado, etc.)
#   3. Renombre: nombre → via_acceso_exp (evitar confusión)
#
# Resultado:
#   via_acceso NaN:   13,835 → 0 (100% cobertura)
#   Categorías:       11 → 13 (limpias y sin duplicados)
#
# Archivos actualizados:
#   data/02_processed/df_alumno.parquet
#   data/02_processed/df_alumno.csv
#
# 📌 Siguiente: Actualizar orquestador f1_m04_dataset_final.ipynb
#               Luego Fase 3 — F3-M01 (P1, P3, P6-P9)
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #e53e3e 0%, #c53030 100%);
#         color: white;
#         padding: 18px 25px;
#         border-radius: 12px;
#         margin: 15px 0;
#         display: flex;
#         align-items: center;
#         justify-content: space-between;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.15);
#     ">
#         <div style="display: flex; align-items: center;">
#             <span style="font-size: 1.5em; margin-right: 12px;" class="animate-pulse">✅</span>
#             <span style="font-size: 1.05em;">M04d completado → vía de acceso corregida</span>
#         </div>
#
#         <span style="
#             background: rgba(255,255,255,0.3);
#             padding: 4px 12px;
#             border-radius: 20px;
#             font-size: 0.85em;
#             margin-left: 10px;
#         ">⏱️ 3.2s</span>
#
#     </div>

# %%
# ============================================================================
# CELDA 11: PIPELINE COMPLETADO
# ============================================================================

mostrar_pipeline(ETAPAS, etapa_actual=5)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: white;
#         border-radius: 12px;
#         padding: 25px;
#         margin: 15px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.1);
#     ">
#         <div style="
#             display: flex;
#             align-items: center;
#             justify-content: space-between;
#         ">
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04a: 8 Tablas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04b: +Preinscripción</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04c: Notas</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">M04d: Vía Acceso</span>
#         </div>
#
#             <div style="
#                 flex: 1;
#                 height: 3px;
#                 background: #e2e8f0;
#                 margin: 0 15px;
#                 position: relative;
#             ">
#                 <div style="
#                     position: absolute;
#                     right: -8px;
#                     top: -5px;
#                     color: #cbd5e0;
#                 ">▶</div>
#             </div>
#
#         <div style="display: flex; align-items: center;">
#             <div class="" style="
#                 width: 50px;
#                 height: 50px;
#                 border-radius: 50%;
#                 background: #38a169;
#                 border: 3px solid #38a169;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#                 font-size: 1.3em;
#                 color: white;
#                 box-shadow: none;
#             ">
#                 ✓
#             </div>
#             <span style="
#                 margin-left: 10px;
#                 font-weight: normal;
#                 color: #2d3748;
#             ">Dataset Final</span>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 12: RESUMEN FINAL
# ============================================================================

import pandas as pd
from src.config import RUTA_PROCESSED
from src.utils import formato_numero_es
fmt = formato_numero_es

path_final = RUTA_PROCESSED / 'df_alumno.parquet'
if path_final.exists():
    _df = pd.read_parquet(path_final)
    _n_reg = len(_df)
    _n_col = len(_df.columns)
    _n_alu = _df['per_id_ficticio'].nunique()
    _size = path_final.stat().st_size / 1024 / 1024
else:
    _n_reg = _n_col = _n_alu = 0
    _size = 0

tiempo_total = tiempo_a + tiempo_b + tiempo_c + tiempo_d

STATS = [
    {'valor': '9',                   'titulo': 'Tablas unidas',  'icono': '📊'},
    {'valor': fmt(_n_reg),           'titulo': 'Registros',      'icono': '📋'},
    {'valor': str(_n_col),           'titulo': 'Columnas',       'icono': '📐'},
    {'valor': f'{tiempo_total:.1f}s','titulo': 'Tiempo total',   'icono': '⏱️'},
]

mostrar_resumen_final(
    titulo='¡M04 COMPLETADO CON ÉXITO!',
    stats=STATS,
    icono='🎉',
    color='verde'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #38a169 0%, #2f855a 100%);
#         border-radius: 16px;
#         padding: 25px;
#         margin: 20px 0;
#         box-shadow: 0 10px 40px rgba(0,0,0,0.2);
#     ">
#         <h3 style="
#             color: white;
#             text-align: center;
#             margin: 0 0 20px 0;
#             font-size: 1.4em;
#         ">
#             <span class="animate-bounce" style="display: inline-block; margin-right: 10px;">🎉</span>
#             ¡M04 COMPLETADO CON ÉXITO!
#         </h3>
#         <div style="
#             background: white;
#             border-radius: 12px;
#             padding: 20px;
#             display: flex;
#             justify-content: space-around;
#             flex-wrap: wrap;
#             gap: 10px;
#         ">
#
#         <div style="
#             text-align: center;
#             padding: 15px;
#             animation: fadeInUp 0.5s ease-out 0.0s forwards;
#             opacity: 0;
#         ">
#             <div style="font-size: 1.5em; margin-bottom: 5px;">📊</div>
#             <div style="font-size: 1.8em; font-weight: bold; color: #276749;">
#                 9
#             </div>
#             <div style="font-size: 0.85em; color: #718096;">Tablas unidas</div>
#         </div>
#
#         <div style="
#             text-align: center;
#             padding: 15px;
#             animation: fadeInUp 0.5s ease-out 0.1s forwards;
#             opacity: 0;
#         ">
#             <div style="font-size: 1.5em; margin-bottom: 5px;">📋</div>
#             <div style="font-size: 1.8em; font-weight: bold; color: #276749;">
#                 109.568
#             </div>
#             <div style="font-size: 0.85em; color: #718096;">Registros</div>
#         </div>
#
#         <div style="
#             text-align: center;
#             padding: 15px;
#             animation: fadeInUp 0.5s ease-out 0.2s forwards;
#             opacity: 0;
#         ">
#             <div style="font-size: 1.5em; margin-bottom: 5px;">📐</div>
#             <div style="font-size: 1.8em; font-weight: bold; color: #276749;">
#                 37
#             </div>
#             <div style="font-size: 0.85em; color: #718096;">Columnas</div>
#         </div>
#
#         <div style="
#             text-align: center;
#             padding: 15px;
#             animation: fadeInUp 0.5s ease-out 0.30000000000000004s forwards;
#             opacity: 0;
#         ">
#             <div style="font-size: 1.5em; margin-bottom: 5px;">⏱️</div>
#             <div style="font-size: 1.8em; font-weight: bold; color: #276749;">
#                 12.6s
#             </div>
#             <div style="font-size: 0.85em; color: #718096;">Tiempo total</div>
#         </div>
#
#         </div>
#     </div>

# %%
# ============================================================================
# CELDA 9: ARCHIVOS GENERADOS
# ============================================================================
#
# Muestra los archivos generados con sus tamaños reales.
# Calcula dinámicamente el tamaño de cada archivo.
# ============================================================================

from IPython.display import HTML, display

# Calcular tamaños dinámicamente
archivos = [
    ('df_alumno.parquet',      RUTA_PROCESSED, '🐍', 'Python / Análisis',          '#3182ce', '#ebf8ff'),
    ('df_alumno.csv',          RUTA_PROCESSED, '📊', 'Tableau / Power BI',          '#38a169', '#f0fff4'),
    ('df_alumno_base.parquet', RUTA_PROCESSED, '📦', 'Intermedio (sin preinscripción)', '#805ad5', '#faf5ff'),
]

items_html = ''
for i, (nombre, ruta, emoji, uso, color, bg) in enumerate(archivos):
    path = ruta / nombre
    if path.exists():
        size = f'{path.stat().st_size / 1024 / 1024:.2f} MB'
    else:
        size = 'No generado'
    items_html += f'''
    <div class="archivo-item" style="background:{bg}; border-left:4px solid {color};
         padding:15px; margin:8px 0; border-radius:10px; display:flex; align-items:center;
         animation:slideIn 0.5s ease-out {0.1+i*0.1}s forwards; opacity:0;">
        <span style="font-size:1.5em; margin-right:15px;">{emoji}</span>
        <div>
            <strong style="color:{color};">{nombre}</strong>
            <p style="margin:3px 0 0 0; color:#718096; font-size:0.85em;">{uso} ({size})</p>
        </div>
    </div>'''

html = f'''
<style>
@keyframes slideIn {{
    from {{ opacity: 0; transform: translateX(-20px); }}
    to {{ opacity: 1; transform: translateX(0); }}
}}
</style>
<div style="background:white; border-radius:12px; padding:20px; margin:15px 0;
     box-shadow:0 4px 15px rgba(0,0,0,0.1);">
    <h4 style="margin:0 0 15px 0; color:#2d3748;">📁 Archivos Generados</h4>
    {items_html}
    <p style="margin-top:15px; color:#718096; font-size:0.85em; text-align:center;">
        📍 Ubicación: <code>{RUTA_PROCESSED}</code>
    </p>
</div>
'''
display(HTML(html))
# Out:
# <style>
# @keyframes slideIn {
#     from { opacity: 0; transform: translateX(-20px); }
#     to { opacity: 1; transform: translateX(0); }
# }
# </style>
# <div style="background:white; border-radius:12px; padding:20px; margin:15px 0;
#      box-shadow:0 4px 15px rgba(0,0,0,0.1);">
#     <h4 style="margin:0 0 15px 0; color:#2d3748;">📁 Archivos Generados</h4>
#
#     <div class="archivo-item" style="background:#ebf8ff; border-left:4px solid #3182ce;
#          padding:15px; margin:8px 0; border-radius:10px; display:flex; align-items:center;
#          animation:slideIn 0.5s ease-out 0.1s forwards; opacity:0;">
#         <span style="font-size:1.5em; margin-right:15px;">🐍</span>
#         <div>
#             <strong style="color:#3182ce;">df_alumno.parquet</strong>
#             <p style="margin:3px 0 0 0; color:#718096; font-size:0.85em;">Python / Análisis (2.29 MB)</p>
#         </div>
#     </div>
#     <div class="archivo-item" style="background:#f0fff4; border-left:4px solid #38a169;
#          padding:15px; margin:8px 0; border-radius:10px; display:flex; align-items:center;
#          animation:slideIn 0.5s ease-out 0.2s forwards; opacity:0;">
#         <span style="font-size:1.5em; margin-right:15px;">📊</span>
#         <div>
#             <strong style="color:#38a169;">df_alumno.csv</strong>
#             <p style="margin:3px 0 0 0; color:#718096; font-size:0.85em;">Tableau / Power BI (31.04 MB)</p>
#         </div>
#     </div>
#     <div class="archivo-item" style="background:#faf5ff; border-left:4px solid #805ad5;
#          padding:15px; margin:8px 0; border-radius:10px; display:flex; align-items:center;
#          animation:slideIn 0.5s ease-out 0.30000000000000004s forwards; opacity:0;">
#         <span style="font-size:1.5em; margin-right:15px;">📦</span>
#         <div>
#             <strong style="color:#805ad5;">df_alumno_base.parquet</strong>
#             <p style="margin:3px 0 0 0; color:#718096; font-size:0.85em;">Intermedio (sin preinscripción) (2.18 MB)</p>
#         </div>
#     </div>
#     <p style="margin-top:15px; color:#718096; font-size:0.85em; text-align:center;">
#         📍 Ubicación: <code>C:\FF\AU_UJI_v2\data\02_processed</code>
#     </p>
# </div>

# %%
# ============================================================================
# CELDA 10: SIGUIENTE PASO
# ============================================================================

mostrar_banner(
    titulo='Siguiente: M05 - Dashboard',
    subtitulo='Dashboard HTML resumen de la Fase 1',
    icono='📌',
    color='morado'
)
# Out:
#
# <style>
# @keyframes fadeInUp {
#     from {
#         opacity: 0;
#         transform: translateY(20px);
#     }
#     to {
#         opacity: 1;
#         transform: translateY(0);
#     }
# }
#
# @keyframes pulse {
#     0%, 100% { transform: scale(1); }
#     50% { transform: scale(1.05); }
# }
#
# @keyframes shimmer {
#     0% { background-position: -200% center; }
#     100% { background-position: 200% center; }
# }
#
# @keyframes spin {
#     from { transform: rotate(0deg); }
#     to { transform: rotate(360deg); }
# }
#
# @keyframes progress {
#     0% { width: 0%; }
#     100% { width: 100%; }
# }
#
# @keyframes bounce {
#     0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#     40% { transform: translateY(-10px); }
#     60% { transform: translateY(-5px); }
# }
#
# @keyframes glow {
#     0%, 100% { box-shadow: 0 0 5px rgba(255,255,255,0.5); }
#     50% { box-shadow: 0 0 20px rgba(255,255,255,0.8), 0 0 30px rgba(255,255,255,0.6); }
# }
#
# .animate-fadeInUp {
#     animation: fadeInUp 0.6s ease-out forwards;
# }
#
# .animate-pulse {
#     animation: pulse 2s ease-in-out infinite;
# }
#
# .animate-bounce {
#     animation: bounce 1s ease infinite;
# }
#
# .animate-glow {
#     animation: glow 2s ease-in-out infinite;
# }
# </style>
#
#     <div class="animate-fadeInUp" style="
#         background: linear-gradient(135deg, #805ad5 0%, #553c9a 100%);
#         padding: 30px 40px;
#         border-radius: 16px;
#         margin: 20px 0;
#         box-shadow: 0 10px 40px rgba(0,0,0,0.2);
#         position: relative;
#         overflow: hidden;
#     ">
#         <div style="
#             position: absolute;
#             top: -50%;
#             left: -50%;
#             width: 200%;
#             height: 200%;
#             background: linear-gradient(
#                 45deg,
#                 transparent 30%,
#                 rgba(255,255,255,0.1) 50%,
#                 transparent 70%
#             );
#             animation: shimmer 3s infinite;
#         "></div>
#         <h2 style="
#             color: white;
#             margin: 0;
#             text-align: center;
#             font-size: 1.8em;
#             text-shadow: 2px 2px 4px rgba(0,0,0,0.2);
#             position: relative;
#         ">
#             <span style="font-size: 1.3em; margin-right: 10px;">📌</span> Siguiente: M05 - Dashboard
#         </h2>
#
#         <p style="color: rgba(255,255,255,0.9); margin: 12px 0 0 0; text-align: center; font-size: 1.1em;">
#             Dashboard HTML resumen de la Fase 1
#         </p>
#
#     </div>

# %% [markdown]
# import pandas as pd
# from src.config import RUTA_PROCESSED
#
# df = pd.read_parquet(RUTA_PROCESSED / 'df_alumno.parquet')
# print(f'Shape: {df.shape}')
# print(f'Columnas: {list(df.columns)}')
# print(f'nota_acceso NaN: {df["nota_acceso"].isna().sum()}')
# print(f'nota_selectividad >14: {(df["nota_selectividad"] > 14).sum()}')
# print(f'via_acceso NaN: {df["via_acceso"].isna().sum()}')
# print(f'"nombre" existe: {"nombre" in df.columns}')
# print(f'"via_acceso_exp" existe: {"via_acceso_exp" in df.columns}')
