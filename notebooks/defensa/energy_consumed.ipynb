# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "src").is_dir():
    ROOT = ROOT.parent

df = pd.read_parquet  # (no, es csv)
csv = ROOT / "data/06_evaluacion/sostenibilidad_defensa/emissions.csv"
df = pd.read_csv(csv)
print("energy_consumed (kWh):", df['energy_consumed'].iloc[-1])
print("emissions (kg CO2eq) :", df['emissions'].iloc[-1])
print("duration (s)         :", df['duration'].iloc[-1])
print("country/region       :", df['country_name'].iloc[-1], "/", df['region'].iloc[-1])

# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / "src").is_dir():
    ROOT = ROOT.parent

csv = ROOT / "data/06_evaluacion/sostenibilidad_defensa/emissions.csv"
df = pd.read_csv(csv)
print("energy_consumed (kWh):", df['energy_consumed'].iloc[-1])
print("emissions (kg CO2eq) :", df['emissions'].iloc[-1])
print("duration (s)         :", df['duration'].iloc[-1])
print("country/region       :", df['country_name'].iloc[-1], "/", df['region'].iloc[-1])
