# %% [markdown]
# # f6_m02_interp_indice.ipynb
# **TFM: Pronóstico del Éxito y del Abandono en los Títulos de Grado de la UJI**
#
# | | |
# |---|---|
# | **Autora** | María José Morte Ruiz |
# | **Institución** | UOC + Universitat Jaume I |
# | **Email** | mjmorteruiz@uoc.edu · morte@uji.es |
# | **Fase** | 6 — Interpretabilidad y Evaluación Final |
# | **Módulo** | M02 — Interpretabilidad Alternativa (Índice de grupo) |
#
# ---
#
# ## 🎯 Qué hace
#
# Página índice del grupo Interpretabilidad Alternativa dentro de la Fase 6.
# Muestra LIME y DiCE con descripción y enlace directo.
#
# ## 📋 Requisitos
#
# - `src/html/render.py` con `render_pagina_desde_fichero()`
#
# ## 📤 Genera
#
# | Archivo | Contenido |
# |---|---|
# | `docs/html/fase6/m02_interpretabilidad_alternativa.html` | Índice del grupo con enlaces a submódulos |
#
# ## 🔄 Flujo
#
# ```
# render_pagina_desde_fichero() → HTML índice de grupo → escribe en disco
# ```
#
# ## ➡️ Siguiente
#
# Ejecutar los submódulos en orden:
# `f6_m02a_lime` → `f6_m02b_dice`

# %%
# ============================================================
# CELDA 1: CONFIGURACIÓN DE RUTAS
# ROOT detectado subiendo niveles hasta encontrar src/
# ============================================================
import sys
from pathlib import Path

ROOT = Path.cwd()
while not (ROOT / 'src').exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
print(f'ROOT: {ROOT}')
# Out:
# ROOT: c:\PRUEBAS\AU_UJI_v2_RUTA_B

# %%
# ============================================================
# CELDA 2: GENERAR HTML ÍNDICE DE GRUPO
# Título incluye fase + grupo (F6-01 corregido).
# Nombres de submódulos incluyen ID: M02a, M02b.
# ============================================================
from src.html.render import render_pagina

contenido = '''<h2 style="color:#2d3748;margin-bottom:8px">Fase 6 — M02: Interpretabilidad Alternativa (Índice de grupo)</h2>
<p style="color:#4a5568;font-size:14px;max-width:800px;margin-bottom:24px">
Grupo de módulos de interpretabilidad alternativa a SHAP.
LIME aproxima el modelo localmente con un modelo lineal.
DiCE genera contrafactuales: ¿qué debería cambiar en un alumno para que el modelo prediga no-abandono?
</p>
<table style="width:100%;border-collapse:collapse;font-size:13px">
<thead><tr style="background:#edf2f7">
  <th style="padding:10px 14px;width:50px"></th>
  <th style="padding:10px 14px;text-align:left">Submódulo</th>
  <th style="padding:10px 14px;width:80px"></th>
</tr></thead>
<tbody>
<tr style="cursor:pointer" onclick="window.location='m02a_lime.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">🍋</td>
  <td style="padding:12px 14px">
    <a href="m02a_lime.html" style="font-weight:600;color:#2d3748;text-decoration:none">M02a — LIME</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">Explicaciones locales con LIME sobre 3 perfiles representativos (TP, VN, zona riesgo).</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#1e4d8c;font-size:13px">Ver →</td>
</tr>
<tr style="cursor:pointer" onclick="window.location='m02b_dice.html'">
  <td style="padding:12px 14px;font-size:20px;text-align:center">🎲</td>
  <td style="padding:12px 14px">
    <a href="m02b_dice.html" style="font-weight:600;color:#2d3748;text-decoration:none">M02b — DiCE</a>
    <div style="font-size:12px;color:#718096;margin-top:3px">Contrafactuales con DiCE (Microsoft): ¿qué cambios mínimos harían que el modelo predijera no-abandono?</div>
  </td>
  <td style="padding:12px 14px;text-align:right;color:#1e4d8c;font-size:13px">Ver →</td>
</tr>
</tbody></table>'''

ruta_html = ROOT / 'docs' / 'html' / 'fase6' / 'm02_interpretabilidad_alternativa.html'
ruta_html.parent.mkdir(parents=True, exist_ok=True)
render_pagina(
    'f6_m02_interp_indice.ipynb',
    contenido,
    ruta_html,
    carpeta_notebook='fase6_evaluacion'
)
print(f'✅ HTML generado: {ruta_html}')
# Out:
# ✅ HTML generado: c:\PRUEBAS\AU_UJI_v2_RUTA_B\docs\html\fase6\m02_interpretabilidad_alternativa.html
