# %%
import pandas as pd
from pathlib import Path

# Detección dinámica de ROOT: subir niveles hasta encontrar la carpeta src/
ROOT = Path.cwd()
while not (ROOT / 'src').exists():
    ROOT = ROOT.parent

ruta = ROOT / 'results' / 'fase6' / 'shap_importancia_comparativa.parquet'
print(f'Existe: {ruta.exists()}')

if ruta.exists():
    df = pd.read_parquet(ruta)
    print(f'\nShape: {df.shape}')
    print(f'\nColumnas: {df.columns.tolist()}')
    print(f'\nÍndice (primeros 5): {df.index.tolist()[:5]}')
    print(f'\nDtypes:')
    print(df.dtypes)
    print(f'\nPrimeras 3 filas:')
    print(df.head(3))
