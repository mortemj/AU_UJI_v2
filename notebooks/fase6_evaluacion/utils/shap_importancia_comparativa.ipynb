# %%
import pandas as pd
from pathlib import Path

# Si estás en notebook: ROOT debe estar definido
# Si no, ajusta esta línea:
ROOT = Path(r'C:\FF\AU_UJI_v2')

ruta = ROOT / 'results' / 'fase6' / 'shap_importancia_comparativa.parquet'
print(f'Existe: {ruta.exists()}')

if ruta.exists():
    df = pd.read_parquet(ruta)
    print(f'\nShape: {df.shape}')
    print(f'\nColumnas: {df.columns.tolist()}')
    print(f'\nÍndice (primeros 5): {df.index.tolist()[:5]}')
    print(f'\nDtypes:')
    print(df.dtypes)
    print(f'\nPrimeras 3 filas:')
    print(df.head(3))
# Out:
# Existe: True
#
# Shape: (27, 8)
#
# Columnas: ['LightGBM', 'MLP', 'EBM', 'rank_ganador', 'rank_mlp', 'rank_ebm', 'rank_medio', 'discrepancia']
#
# Índice (primeros 5): ['anios_gap', 'anios_sin_beca', 'cred_repetidos', 'cred_superados_anio_1er', 'cupo']
#
# Dtypes:
# LightGBM        float64
# MLP             float64
# EBM             float64
# rank_ganador      int64
# rank_mlp          int64
# rank_ebm          int64
# rank_medio      float64
# discrepancia      int64
# dtype: object
#
# Primeras 3 filas:
#                 LightGBM       MLP       EBM  rank_ganador  rank_mlp  \
# anios_gap       0.014367  0.003373  0.006031            22        17
# anios_sin_beca  0.423132  0.057736  0.912837             5         4
# cred_repetidos  0.447872  0.066051  0.301256             4         3
#
#                 rank_ebm  rank_medio  discrepancia
# anios_gap             25   21.333333             8
# anios_sin_beca         2    3.666667             3
# ...
