# %%
import pandas as pd
df = pd.read_parquet(r'C:\FF\AU_UJI_v2\data\05_modelado\results\resultados_maestro.parquet')
print(df[['modelo','estrategia','f1_test','recall_test','auc_test','tiempo_s']]
      .sort_values('f1_test', ascending=False).head(10).to_string())
# Out:
#       modelo estrategia  f1_test  recall_test  auc_test  tiempo_s
# 0    XGBoost       none   0.8336       0.8007    0.9573     4.110
# 3   LightGBM       none   0.8334       0.8048    0.9564     4.562
# 14       MLP       none   0.8311       0.8119    0.9531     5.683
# 15       MLP   balanced   0.8311       0.8119    0.9531     8.842
# 1    XGBoost   balanced   0.8298       0.8760    0.9572     4.638
# 2    XGBoost      smote   0.8290       0.8144    0.9561     3.960
# 5   LightGBM      smote   0.8279       0.8144    0.9551     6.519
# 9   CatBoost       none   0.8274       0.7895    0.9536    10.697
# 7   Stacking       none   0.8273       0.8073    0.9535  2051.132
# 6   Stacking   balanced   0.8273       0.8073    0.9535   525.189
